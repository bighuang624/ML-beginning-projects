# %%
from __future__ import print_function

import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop

batch_size = 128
num_classes = 10   # 输出层单元数
epochs = 20

# %%
# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# %%
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# 60000 train samples
# 10000 test samples

# %%
# convert class vectors to binary class matrices(One-hot 化)
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 512)               401920
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
             optimizer=RMSprop(),
             metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train,
                   batch_size=batch_size,
                   epochs=epochs,
                   verbose=1,    # 日志显示模式。 0 = 安静模式, 1 = 进度条, 2 = 每轮一行
                   validation_data=(x_test, y_test))

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 17s 284us/step - loss: 0.2486 - acc: 0.9236 - val_loss: 0.1125 - val_acc: 0.9642
# Epoch 2/20
#  - ETA: 6s - loss: 0.1055 - acc: 0.9678
# Epoch 3/20
# 60000/60000 [==============================] - 17s 279us/step - loss: 0.0757 - acc: 0.9773 - val_loss: 0.0695 - val_acc: 0.9798
# Epoch 4/20
# 60000/60000 [==============================] - 26s 430us/step - loss: 0.0597 - acc: 0.9821 - val_loss: 0.0790 - val_acc: 0.9782
# Epoch 5/20
#  - ETA: 30s - loss: 0.0393 - acc: 0.9863
# Epoch 6/20
#  - ETA: 0s - loss: 0.0431 - acc: 0.9868
# Epoch 7/20
#  - ETA: 12s - loss: 0.0365 - acc: 0.9892
# Epoch 8/20
#  - ETA: 2s - loss: 0.0342 - acc: 0.9898
# Epoch 9/20
# 60000/60000 [==============================] - 24s 403us/step - loss: 0.0302 - acc: 0.9913 - val_loss: 0.0876 - val_acc: 0.9821
# Epoch 10/20
#  - ETA: 20s - loss: 0.0280 - acc: 0.9917
# Epoch 11/20
#  - ETA: 23s - loss: 0.0188 - acc: 0.9902
# Epoch 12/20
#  - ETA: 10s - loss: 0.0214 - acc: 0.9942
# Epoch 13/20
#  - ETA: 4s - loss: 0.0235 - acc: 0.9932
# Epoch 14/20
#  - ETA: 13s - loss: 0.0223 - acc: 0.9933
# Epoch 15/20
# 60000/60000 [==============================] - 19s 310us/step - loss: 0.0214 - acc: 0.9941 - val_loss: 0.0799 - val_acc: 0.9838
# Epoch 16/20
# 60000/60000 [==============================] - 17s 280us/step - loss: 0.0213 - acc: 0.9945 - val_loss: 0.0945 - val_acc: 0.9837
# Epoch 17/20
# 60000/60000 [==============================] - 22s 371us/step - loss: 0.0177 - acc: 0.9952 - val_loss: 0.1029 - val_acc: 0.9827
# Epoch 18/20
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.0179 - acc: 0.9954 - val_loss: 0.1070 - val_acc: 0.9826
# Epoch 19/20
#  - ETA: 1s - loss: 0.0209 - acc: 0.9951
# Epoch 20/20
#  - ETA: 8s - loss: 0.0202 - acc: 0.9948
# Test loss: 0.10856771944053585
# Test accuracy: 0.9853
